# %%
# %cd /home/andreasstillits/coding/Leaves1D/PNAS_REVIEW

from review.utils.plotfunctions import plot_sensitivity_map 


plot_sensitivity_map("files/nonlinear_figure3C/sensitivities_mu0.00_.txt")
plot_sensitivity_map("files/nonlinear_figure3C/sensitivities_mu8.00_.txt")
# Out:
# /home/andreasstillits/coding/Leaves1D/PNAS_REVIEW
