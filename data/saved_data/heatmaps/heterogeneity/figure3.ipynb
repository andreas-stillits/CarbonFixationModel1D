# %%
# defining root location of the project on local system (change this to your own path after pulling)
import numpy as np 
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# set up plotting config
mpl.rcParams['mathtext.fontset'] = 'stix'  # or 'dejavusans', 'cm', 'custom'
mpl.rcParams['font.family'] = 'STIXGeneral'  # Matches STIX math font
# set tick font size
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
# set default fontsize
mpl.rcParams['font.size'] = 16

# define root
ROOT = "/home/andreasstillits/coding/Leaves1D/"
# %pwd
# Out:
# '/home/andreasstillits/coding/Leaves1D/figures/scripts'

# %% [markdown]
# ### Helper functions

# %%
def map_data_values(df: pd.DataFrame, map: np.ndarray, vmin: float = 0.01, vmax: float = 100) -> np.ndarray:
    taus_data = df['tau'].to_numpy()
    gammas_data = df['gamma'].to_numpy()
    N_gamma, N_tau = map.shape 
    taus = np.exp(np.linspace(np.log(vmin), np.log(vmax), N_tau))
    gammas = np.exp(np.linspace(np.log(vmin), np.log(vmax), N_gamma))
    log_taus = np.log(taus)
    log_gammas = np.log(gammas)
    
    values = []
    for tau_data, gamma_data in zip(taus_data, gammas_data):
        # Handle out-of-bounds values by clipping to grid range via nearest neighbour
        if (tau_data <= taus[0]) or (tau_data >= taus[-1]) or (gamma_data <= gammas[0]) or (gamma_data >= gammas[-1]):
            idx_tau = int(np.argmin(np.abs(taus - tau_data)))
            idx_gamma = int(np.argmin(np.abs(gammas - gamma_data)))
            values.append(map[idx_gamma, idx_tau])
            continue

        # Work in log-space for interpolation weights
        log_tau_data = np.log(tau_data)
        log_gamma_data = np.log(gamma_data)

        # Find indices of the two neighbouring grid points in each direction (in log-space)
        idx_tau_upper = int(np.searchsorted(log_taus, log_tau_data, side="right"))
        idx_tau_lower = idx_tau_upper - 1
        idx_gamma_upper = int(np.searchsorted(log_gammas, log_gamma_data, side="right"))
        idx_gamma_lower = idx_gamma_upper - 1

        x0, x1 = log_taus[idx_tau_lower], log_taus[idx_tau_upper]
        y0, y1 = log_gammas[idx_gamma_lower], log_gammas[idx_gamma_upper]

        f00 = map[idx_gamma_lower, idx_tau_lower]
        f10 = map[idx_gamma_lower, idx_tau_upper]
        f01 = map[idx_gamma_upper, idx_tau_lower]
        f11 = map[idx_gamma_upper, idx_tau_upper]

        tx = (log_tau_data - x0) / (x1 - x0)
        ty = (log_gamma_data - y0) / (y1 - y0)

        value = (
            (1 - tx) * (1 - ty) * f00 +
            tx * (1 - ty) * f10 +
            (1 - tx) * ty * f01 +
            tx * ty * f11
)
        values.append(value)

    return np.array(values)
    
def plot_map(ax: plt.Axes, map: np.ndarray, cmap: ListedColormap, norm: BoundaryNorm, vmin: float = 0.01, vmax: float = 100, inset: bool = False):
    """Helper function to set standard plot settings for (tau,gamma) figures."""
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_xlim(vmin, vmax)
    ax.set_ylim(vmin, vmax)
    ax.plot([1, 1], [vmin, vmax], color="grey", linestyle="-.", zorder=2)
    ax.plot([vmin, vmax], [1, 1], color="grey", linestyle="-.", zorder=2)

    df = pd.read_csv(ROOT + "data/saved_data/Knauer2022_hypostomatous.csv", decimal=',', sep=';')
    dfMomayyeziW = pd.read_csv(ROOT + 'data/saved_data/Momayyezi2022_watered.csv', sep=';', decimal=',')
    dfMomayyeziDH = pd.read_csv(ROOT + 'data/saved_data/Momayyezi2022_dehydrated.csv', sep=';', decimal=',')

    markersize = 35 if not inset else 10

    ax.scatter(df['tau'], df['gamma'], color="darkblue", marker="o", zorder=3, label="Knauer et al.", s=markersize)
    ax.scatter(dfMomayyeziW['tau'], dfMomayyeziW['gamma'], color="teal", marker="o", zorder=3, label="Momayyezi et al. (watered)", s=markersize)
    ax.scatter(dfMomayyeziDH['tau'], dfMomayyeziDH['gamma'], color="darkred", marker="o", zorder=3, label="Momayyezi et al. (dehydrated)", s=markersize)
    
    N = map.shape[0]
    taus = np.exp(np.linspace(np.log(vmin), np.log(vmax), N))
    gammas = np.exp(np.linspace(np.log(vmin), np.log(vmax), N))
    im = ax.pcolormesh(taus, gammas, map, shading="nearest", cmap=cmap, norm=norm)    
    if not inset:
        ax.set_xlabel(r"Absorption balance $\tau$ []")
        ax.set_ylabel(r"Transport balance $\gamma$ []")
    else:
        ax.tick_params(axis="x", labelbottom=False)
        ax.tick_params(axis="y", labelleft=False)
    return im

def make_colormap(basis: str, bounds: list) -> tuple[ListedColormap, BoundaryNorm]:
    cmap = plt.get_cmap(basis, len(bounds))
    colors = cmap(range(len(bounds)-1))
    colors[0] = (1, 1, 1, 1)  # set the first color to white
    cmap = ListedColormap(colors)
    norm = BoundaryNorm(bounds, cmap.N)
    return cmap, norm 

def std_histogram(ax: plt.Axes, xlabel: str = "Error (%)") -> None:
    ax.set_ylabel('Count')
    ax.set_xlabel(xlabel)
    ax.set_yscale('log')
    ax.legend(loc="upper right", fontsize=10)
    return

def describe_errors(errors: np.ndarray, *thresholds: float) -> None:
    print(f"Mean error: {np.mean(errors):.2f}%")
    print(f"Median error: {np.median(errors):.2f}%")
    print(f"Max error: {np.max(errors):.2f}%")
    print(f"Min error: {np.min(errors):.2f}%")
    for threshold in thresholds:
        print(f"Percentage of errors below {threshold}%: {100 * np.sum(errors < threshold)/len(errors):.2f}%")
    print("\n")

# %% [markdown]
# ### Figure 3A

# %%
# load data 
df = pd.read_csv(ROOT + "data/saved_data/Knauer2022_hypostomatous.csv", decimal=',', sep=';')


# load 1D error map
error1D = 100 * np.loadtxt(ROOT + "data/saved_data/heatmaps/gradients/1Dv0D.txt", delimiter=";").T
# load 3D error map
error3D = 100 * np.loadtxt(ROOT + "data/saved_data/heatmaps/gradients/3Dv0D_typical.txt", delimiter=";").T

cmap, norm = make_colormap('Reds', bounds=[0, 5, 10, 25, 50, 100, 200])

# create figure
fig, (ax_hist, ax_map) = plt.subplots(
    2, 1,
    gridspec_kw={"height_ratios": [1, 4], "hspace": 0.25},
    figsize=(7, 7)
 )

# map error values to data points
error1D_data = map_data_values(df, error1D)
error3D_data = map_data_values(df, error3D)

# create histogram of errors
bins = np.linspace(0, 80, 41)
ax_hist.hist(error3D_data, bins=bins, alpha=0.7, color="#3a3939ff", edgecolor="black", label="3D typical")
ax_hist.hist(error1D_data, bins=bins, alpha=0.8, color="lightgrey", edgecolor="black", label="1D model")
std_histogram(ax_hist)

# plot 3D error map and data
im3d = plot_map(ax_map, error3D, cmap, norm)


# create an inset axes and plot 1D error map as a zoom-in
ax_inset = inset_axes(ax_map, width="35%", height="35%", loc='lower right', borderpad=0.5)
im1d = plot_map(ax_inset, error1D, cmap, norm, inset=True)
ax_inset.set_title("1D model", fontsize=12)

fig.colorbar(im3d, ax=[ax_map, ax_hist], label=r'Error in $A_N$ from neglecting $CO_2$ gradients (%)')

plt.savefig(ROOT + "figures/vectorgraphics/figure3/figure3A.svg")
plt.savefig(ROOT + "figures/vectorgraphics/figure3/figure3A.png", dpi=300)
plt.show()


print("3D model error statistics:")
describe_errors(error3D_data, 10)
# Out:
# 3D model error statistics:
# Mean error: 14.63%
# Median error: 9.73%
# Max error: 120.90%
# Min error: 0.78%
# Percentage of errors below 10%: 50.57%

# %% [markdown]
# ### Figure 3B

# %%
# load data 
df = pd.read_csv(ROOT + "data/saved_data/Knauer2022_hypostomatous.csv", decimal=',', sep=';')

# load sensitivity maps 
error_dense = 100 * np.loadtxt(ROOT + "data/saved_data/heatmaps/lateral/3Dv1D_dense.txt", delimiter=";").T
error_sparse = 100 * np.loadtxt(ROOT + "data/saved_data/heatmaps/lateral/3Dv1D_sparse.txt", delimiter=";").T
error_typical = 100 * np.loadtxt(ROOT + "data/saved_data/heatmaps/lateral/3Dv1D_typical.txt", delimiter=";").T

cmap, norm = make_colormap('Greens', bounds=[0, 5, 10, 25, 50, 100, 200])

# create figure
fig, (ax_hist, ax_map) = plt.subplots(
    2, 1,
    gridspec_kw={"height_ratios": [1, 4], "hspace": 0.25},
    figsize=(7, 7)
 )

# map sensitivity values to data points
error_typical_data = map_data_values(df, error_typical)
error_dense_data = map_data_values(df, error_dense)
error_sparse_data = map_data_values(df, error_sparse)

# create histogram of errors
bins = np.linspace(0, 80, 41)
#ax_hist.hist(sensitivity3D_data, bins=bins, alpha=0.7, color="darkred", edgecolor="black", label="3D model")
ax_hist.hist(error_sparse_data, bins=bins, alpha=0.7, color="#3a3939ff", edgecolor="black", label="sparse")
ax_hist.hist(error_typical_data, bins=bins, alpha=0.8, color="darkseagreen", edgecolor="black", label="typical")
ax_hist.hist(error_dense_data, bins=bins, alpha=1.0, color="lightgrey", edgecolor="black", label="dense")
std_histogram(ax_hist, xlabel="Error (%)")

# plot the typical case
imTypical = plot_map(ax_map, error_typical, cmap, norm)

# plot the dense case as an inset
ax_inset_dense = inset_axes(ax_map, width="35%", height="35%", loc='lower right', borderpad=0.5)
imDense = plot_map(ax_inset_dense, error_dense, cmap, norm, inset=True)
ax_inset_dense.set_title("Dense", fontsize=12)

# plot the sparse case as an inset
ax_inset_sparse = inset_axes(ax_map, width="35%", height="35%", loc='upper left', borderpad=0.5)
imSparse = plot_map(ax_inset_sparse, error_sparse, cmap, norm, inset=True)
ax_inset_sparse.set_title("Sparse", fontsize=12)



fig.colorbar(imTypical, ax=[ax_map, ax_hist], label=r'Error in $A_N$ from neglecting lateral diffusion (%)')
plt.savefig(ROOT + "figures/vectorgraphics/figure3/figure3B.svg")
plt.savefig(ROOT + "figures/vectorgraphics/figure3/figure3B.png", dpi=300)
plt.show()

print("DENSE model error statistics:")
describe_errors(error_dense_data, 10)

print("TYPICAL model error statistics:")
describe_errors(error_typical_data, 10)

print("SPARSE model error statistics:")
describe_errors(error_sparse_data, 10)
# Out:
# DENSE model error statistics:
# Mean error: 2.93%
# Median error: 2.11%
# Max error: 19.12%
# Min error: 0.49%
# Percentage of errors below 10%: 95.40%
#
#
# TYPICAL model error statistics:
# Mean error: 10.19%
# Median error: 7.13%
# Max error: 71.75%
# Min error: 0.70%
# Percentage of errors below 10%: 65.52%
#
#
# SPARSE model error statistics:
# Mean error: 25.41%
# Median error: 17.92%
# Max error: 178.63%
# Min error: 1.08%
# Percentage of errors below 10%: 18.97%

# %% [markdown]
# ### Figure 3C

# %%
# load data 
df = pd.read_csv(ROOT + "data/saved_data/Knauer2022_hypostomatous.csv", decimal=',', sep=';')

# load heterogeneity maps for contrast 1:2 and 1:4
error2 = 100 * np.loadtxt(ROOT + "data/saved_data/heatmaps/heterogeneity/3D_typical_contrast_0.50.txt", delimiter=";").T
error5 = 100 * np.loadtxt(ROOT + "data/saved_data/heatmaps/heterogeneity/3D_typical_contrast_0.20.txt", delimiter=";").T  

# Make discrete colormap
# colorN = 12
# base = plt.get_cmap('Blues')
# colors = base(np.linspace(0.2, 1, colorN - 1))  # skip very light blues
# colors[0] = (1, 1, 1, 1)  # set zero bin to pure white
# cmap = ListedColormap(colors)
# bounds = np.linspace(0, 20, colorN - 1)
# norm = BoundaryNorm(bounds, cmap.N)
cmap, norm = make_colormap('Blues', bounds=[0, 5, 10, 25, 50, 100, 200])

# create figure
fig, (ax_hist, ax_map) = plt.subplots(
    2, 1,
    gridspec_kw={"height_ratios": [1, 4], "hspace": 0.25},
    figsize=(7, 7)
 )

# map error values to data points
error2_data = map_data_values(df, error2)
error5_data = map_data_values(df, error5)

# create histogram of errors
bins = np.linspace(0, 80, 41)
ax_hist.hist(error5_data, bins=bins, alpha=0.7, color="#3a3939ff", edgecolor="black", label="contrast 1 : 5")
ax_hist.hist(error2_data, bins=bins, alpha=0.8, color="lightgrey", edgecolor="black", label="contrast 1 : 2")
std_histogram(ax_hist, xlabel="Error (%)")

# plot 3D error map and data
im5 = plot_map(ax_map, error5, cmap, norm)

# create an inset axes and plot sensitivity3D as a zoomed-in map
ax_inset = inset_axes(ax_map, width="35%", height="35%", loc='lower right', borderpad=0.5)
im2 = plot_map(ax_inset, error2, cmap, norm, inset=True)
ax_inset.set_title("Contrast 1 : 2", fontsize=10)

fig.colorbar(im5, ax=[ax_map, ax_hist], label=r'Error in $A_N$ to axial heterogeneity (%)')
plt.savefig(ROOT + "figures/vectorgraphics/figure3/figure3C.svg")
plt.savefig(ROOT + "figures/vectorgraphics/figure3/figure3C.png", dpi=300)
plt.show()


print("Contrast of 1:2")
describe_errors(error2_data, 10)

print("Contrast of 1:5")
describe_errors(error5_data, 10)
# Out:
# Contrast of 1:2
# Mean error: 1.76%
# Median error: 1.35%
# Max error: 9.08%
# Min error: 0.03%
# Percentage of errors below 10%: 100.00%
#
#
# Contrast of 1:5
# Mean error: 1.87%
# Median error: 1.41%
# Max error: 10.97%
# Min error: 0.02%
# Percentage of errors below 10%: 98.85%
