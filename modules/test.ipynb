# %%
import leaf_model as lm 


leaf = lm.Leaf(1, 1, 0.1, rho=(0.5, 0.6, 0.6))
leaf.calculate_steady_state_solution()
leaf.display_solution() 

print(leaf.deltas.min(), leaf.deltas.max())
# Out:
# 0.7142857142857143 1.4285714285714286
